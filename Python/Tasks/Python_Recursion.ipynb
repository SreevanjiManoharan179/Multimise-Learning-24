# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

print(factorial(5))
# Out:
# 120

# %%
def octal_to_binary(octal):
    def helper(octal):
        if octal == 0:
            return ""
        else:
            return helper(octal // 8) + bin(octal % 8)[2:].zfill(3)

    return helper(octal).lstrip('0') or '0'

print(octal_to_binary(345))
# Out:
# 101011001

# %%
def sum_of_n_squared(n):
    def sum_up_to(m):
        if m == 0:
            return 0
        else:
            return m + sum_up_to(m - 1)

    return sum_up_to(n * n)

print(sum_of_n_squared(3))
# Out:
# 45

# %%
def sum_of_n(n):
    if n == 0:
        return 0
    else:
        return n + sum_of_n(n - 1)

print(sum_of_n(5))
# Out:
# 15

# %%
def gcd(a, b):
    if b == 0:
        return a
    else:
        return gcd(b, a % b)

print(gcd(48, 18))
# Out:
# 6

# %%
def fibonacci(n):
    if n <= 1:
        return n
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

print(fibonacci(10))
print(fibonacci(20))
print(fibonacci(30))
print(fibonacci(40))
# Out:
# 55
# 6765
# 832040
# 102334155

# %%
def find_max(lst):
    if len(lst) == 1:
        return lst[0]
    else:
        max_of_rest = find_max(lst[1:])
        return lst[0] if lst[0] > max_of_rest else max_of_rest

print(find_max([3, 1, 4, 1, 5, 9, 2]))
# Out:
# 9

# %%
def power(base, exp):
    if exp == 0:
        return 1
    else:
        return base * power(base, exp - 1)

print(power(2, 3))
# Out:
# 8

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

def combination(n, r):
    return factorial(n) // (factorial(r) * factorial(n - r))

print(combination(4, 2))
# Out:
# 6
